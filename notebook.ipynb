# %% [markdown]
# # Proyek Analisis Data: Bike Sharing
# - **Nama:** Gesa Rizky Nugraha
# - **Email:** gesarizkynugraha@gmail.com
# - **ID Dicoding:** gesarizky

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana kondisi penyewaan terhadap perubahan musim?
# - Bagaimana kondisi penyewaan sepeda pada hari kerja vs libur?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_df = pd.read_csv('day.csv')
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour_df = pd.read_csv('hour.csv')
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print('Jumlah duplikasi: ', day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
print('Jumlah duplikasi: ', hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# **Insight:**
# - dteday harusnya tipe data datetime
# - nama seasons ganti menjadi string
# - data year ganti menjadi 2011 dan 2012

# %% [markdown]
# ### Cleaning Data

# %%
day_df['dteday'] = pd.to_datetime(day_df['dteday'])
day_df['day_of_week'] = day_df['dteday'].dt.day_name()

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instant      731 non-null    int64
#  1   dteday       731 non-null    datetime64[ns]
#  2   season       731 non-null    int64
#  3   yr           731 non-null    int64
#  4   mnth         731 non-null    int64
#  5   holiday      731 non-null    int64
#  6   weekday      731 non-null    int64
#  7   workingday   731 non-null    int64
#  8   weathersit   731 non-null    int64
#  9   temp         731 non-null    float64
#  10  atemp        731 non-null    float64
#  11  hum          731 non-null    float64
#  12  windspeed    731 non-null    float64
#  13  casual       731 non-null    int64
#  14  registered   731 non-null    int64
#  15  cnt          731 non-null    int64
#  16  day_of_week  731 non-null    object
# dtypes: datetime64[ns](1), float64(4), int64(11), object(1)
# ...

# %%
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])
hour_df['day_of_week'] = hour_df['dteday'].dt.day_name()

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instant      17379 non-null  int64
#  1   dteday       17379 non-null  datetime64[ns]
#  2   season       17379 non-null  int64
#  3   yr           17379 non-null  int64
#  4   mnth         17379 non-null  int64
#  5   hr           17379 non-null  int64
#  6   holiday      17379 non-null  int64
#  7   weekday      17379 non-null  int64
#  8   workingday   17379 non-null  int64
#  9   weathersit   17379 non-null  int64
#  10  temp         17379 non-null  float64
#  11  atemp        17379 non-null  float64
#  12  hum          17379 non-null  float64
#  13  windspeed    17379 non-null  float64
#  14  casual       17379 non-null  int64
#  15  registered   17379 non-null  int64
#  16  cnt          17379 non-null  int64
#  17  day_of_week  17379 non-null  object
# ...

# %%
season_mapping = {
    1: 'Spring',
    2: 'Summer',
    3: 'Fall',
    4: 'Winter'
}

day_df['season'] = day_df['season'].map(season_mapping)

# %%
print(day_df['season'].unique())
# Out:
# ['Spring' 'Summer' 'Fall' 'Winter']

# %%
season_mapping = {
    1: 'Spring',
    2: 'Summer',
    3: 'Fall',
    4: 'Winter'
}

hour_df['season'] = hour_df['season'].map(season_mapping)

# %%
print(hour_df['season'].unique())
# Out:
# ['Spring' 'Summer' 'Fall' 'Winter']

# %%
year_mapping = {
    0: '2011',
    1: '2012'
}

day_df['yr'] = day_df['yr'].map(year_mapping)

# %%
print(day_df['yr'].unique())
# Out:
# ['2011' '2012']

# %%
year_mapping = {
    0: '2011',
    1: '2012'
}

hour_df['yr'] = hour_df['yr'].map(year_mapping)

# %%
print(hour_df['yr'].unique())
# Out:
# ['2011' '2012']

# %%
day_df.head()
# Out:
#    instant     dteday  season    yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01  Spring  2011     1        0        6           0
# 1        2 2011-01-02  Spring  2011     1        0        0           0
# 2        3 2011-01-03  Spring  2011     1        0        1           1
# 3        4 2011-01-04  Spring  2011     1        0        2           1
# 4        5 2011-01-05  Spring  2011     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt day_of_week
# 0   985    Saturday
# 1   801      Sunday
# ...

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instant      731 non-null    int64
#  1   dteday       731 non-null    datetime64[ns]
#  2   season       731 non-null    object
#  3   yr           731 non-null    object
#  4   mnth         731 non-null    int64
#  5   holiday      731 non-null    int64
#  6   weekday      731 non-null    int64
#  7   workingday   731 non-null    int64
#  8   weathersit   731 non-null    int64
#  9   temp         731 non-null    float64
#  10  atemp        731 non-null    float64
#  11  hum          731 non-null    float64
#  12  windspeed    731 non-null    float64
#  13  casual       731 non-null    int64
#  14  registered   731 non-null    int64
#  15  cnt          731 non-null    int64
#  16  day_of_week  731 non-null    object
# dtypes: datetime64[ns](1), float64(4), int64(9), object(3)
# ...

# %%
hour_df.head()
# Out:
#    instant     dteday  season    yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01  Spring  2011     1   0        0        6           0
# 1        2 2011-01-01  Spring  2011     1   1        0        6           0
# 2        3 2011-01-01  Spring  2011     1   2        0        6           0
# 3        4 2011-01-01  Spring  2011     1   3        0        6           0
# 4        5 2011-01-01  Spring  2011     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1
#
#   day_of_week
# 0    Saturday
# 1    Saturday
# 2    Saturday
# 3    Saturday
# ...

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instant      17379 non-null  int64
#  1   dteday       17379 non-null  datetime64[ns]
#  2   season       17379 non-null  object
#  3   yr           17379 non-null  object
#  4   mnth         17379 non-null  int64
#  5   hr           17379 non-null  int64
#  6   holiday      17379 non-null  int64
#  7   weekday      17379 non-null  int64
#  8   workingday   17379 non-null  int64
#  9   weathersit   17379 non-null  int64
#  10  temp         17379 non-null  float64
#  11  atemp        17379 non-null  float64
#  12  hum          17379 non-null  float64
#  13  windspeed    17379 non-null  float64
#  14  casual       17379 non-null  int64
#  15  registered   17379 non-null  int64
#  16  cnt          17379 non-null  int64
#  17  day_of_week  17379 non-null  object
# ...

# %% [markdown]
# **Insight:**
# - dteday sudah di ganti type datanya dan saya menambahkan tuple day_of_week yang berisi nama hari
# - season dan year sudah berganti

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore day_df

# %%
day_df.describe(include="all")
# Out:
#            instant               dteday season    yr        mnth     holiday  \
# count   731.000000                  731    731   731  731.000000  731.000000
# unique         NaN                  NaN      4     2         NaN         NaN
# top            NaN                  NaN   Fall  2012         NaN         NaN
# freq           NaN                  NaN    188   366         NaN         NaN
# mean    366.000000  2012-01-01 00:00:00    NaN   NaN    6.519836    0.028728
# min       1.000000  2011-01-01 00:00:00    NaN   NaN    1.000000    0.000000
# 25%     183.500000  2011-07-02 12:00:00    NaN   NaN    4.000000    0.000000
# 50%     366.000000  2012-01-01 00:00:00    NaN   NaN    7.000000    0.000000
# 75%     548.500000  2012-07-01 12:00:00    NaN   NaN   10.000000    0.000000
# max     731.000000  2012-12-31 00:00:00    NaN   NaN   12.000000    1.000000
# std     211.165812                  NaN    NaN   NaN    3.451913    0.167155
#
# ...

# %%
# Menghitung jumlah penyewaan berdasarkan musim
season_rentals = day_df.groupby('season')['cnt'].sum()

season_rentals.head()
# Out:
# season
# Fall      1061129
# Spring     471348
# Summer     918589
# Winter     841613
# Name: cnt, dtype: int64

# %%
# Perbandingan penggunaan sepeda pada hari kerja vs libur
workingday_rentals = day_df.groupby('workingday')['cnt'].sum()

workingday_rentals.head()
# Out:
# workingday
# 0    1000269
# 1    2292410
# Name: cnt, dtype: int64

# %%
# Perbandingan penggunaan sepeda berdasarkan tahun
year_rentals = day_df.groupby('yr')['cnt'].sum()

year_rentals.head()
# Out:
# yr
# 2011    1243103
# 2012    2049576
# Name: cnt, dtype: int64

# %% [markdown]
# **Insight:**
# - Identifikasi distribusi jumlah penggunaan sepeda untuk melihat apakah terdapat outlier atau pola distribusi tertentu.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana kondisi penyewaan terhadap perubahan musim?

# %%
plt.figure(figsize=(10, 5))
ax = season_rentals.plot(kind='bar', color=['orange', 'springgreen', 'brown', 'lightskyblue'])
plt.title('Jumlah Penyewaan Sepeda per Musim')
plt.xlabel('Musim')
plt.ylabel('Jumlah Penyewaan')
plt.xticks(rotation=45)
ax.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Bagaimana kondisi penyewaan sepeda pada hari kerja vs libur?

# %%
plt.figure(figsize=(6, 4))
ax = workingday_rentals.plot(kind='bar', color=['lightseagreen', 'lightcoral'])
plt.title('Jumlah Penyewaan Sepeda pada Hari Kerja vs Hari Libur')
plt.xlabel('Working Day')
plt.ylabel('Rata-rata Penyewaan')
plt.xticks([0, 1], ['Libur', 'Hari Kerja'], rotation=0)
ax.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# **Insight:**
# - diketahui **fall** adalah musim Favorit penyewa dan **spring** adalah musim tersedikit penyewa
# - diketahui **hari kerja** adalah hari terbanyak penyewa sepeda

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Musim sangat berpengaruh terhadap tingkah laku penyewaan sepeda seperti di perkirakan bahwa musim fall adalah musim favorit penyewa karena kondisi cuaca yang sangat mendukung untuk bersepeda, sangat diluar dugaan untuk musim yang paling sedikit penyewa adalah spring
# - Para penyewa sepeda lebih banyak pada saat hari kerja dibandingkan hari libur dapat disimpulkan bahwa kebanyakan penyewa menggunakan fasilitas umum seperti sewa sepeda untuk berangkat kerja ke kantor

# %%
day_df.to_csv("main_data.csv", index=False)
